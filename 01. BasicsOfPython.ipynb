# %% [markdown]
# # Expressions

# %%
12
# Out:
# 12

# %%
-2 - 78
# Out:
# -80

# %% [markdown]
# ![expressions.png](attachment:expressions.png)

# %%
7 - 2
# Out:
# 5

# %%
 7 + 2
# Out:
# 9

# %%
7 * 2
# Out:
# 14

# %%
7 / 2
# Out:
# 3.5

# %%
7 // 2
# Out:
# 3

# %%
7 % 2
# Out:
# 1

# %% [markdown]
# ![mod.png](attachment:mod.png)

# %%
25//4
# Out:
# 6

# %%
25%4
# Out:
# 1

# %%
type(-2.0  -8)
# Out:
# float

# %%
type(4 / 2)
# Out:
# float

# %%
1 / 2
# Out:
# 0.5

# %%
7 % 3
# Out:
# 1

# %%
15 % 2
# Out:
# 1

# %%
1 / 2.0
# Out:
# 0.5

# %%
type(1)
# Out:
# int

# %%
type(1/2)
# Out:
# float

# %%
1/2.0 + 1/4.0
# Out:
# 0.75

# %%
2.1 + 5.3
# Out:
# 7.4

# %%
2 + 2 * 2
# Out:
# 6

# %%
(2 + 2) * 2 # overriding precedence
# Out:
# 8

# %% [markdown]
# See more about precedence here: https://docs.python.org/3/reference/expressions.html#operator-precedence

# %% [markdown]
# ## Booleon Expression / Conditional Expression

# %%
3 == 7/2
# Out:
# False

# %%
3 < 4        # conditional expression
# Out:
# True

# %%
3 == 3
# Out:
# True

# %%
a3 == 3   # ignore the *details* of the error for now
a3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-682e27535569> in <module>()
# ----> 1 a3 == 3   # ignore the *details* of the error for now
#       2 a3
#
# NameError: name 'a3' is not defined

# %%
3 > 4
# Out:
# False

# %%
3 >= 3
# Out:
# True

# %%
2 <= 1
# Out:
# False

# %% [markdown]
# ## Other types of expressions

# %%
'abc' #String
# Out:
# 'abc'

# %%
type("xyz" )
# Out:
# str

# %%
"""This is a multi line string
it can span multiple lines"""
# Out:
# 'This is a multi line string\nit can span multiple lines'

# %%
"ab" + "cd"
# Out:
# 'abcd'

# %%
type("ab")
# Out:
# str

# %%
("a-" * 3) * 5
# Out:
# 'a-a-a-a-a-a-a-a-a-a-a-a-a-a-a-'

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
True or False and False or False
# Out:
# True

# %%
(True or False) and (False or False)
# Out:
# False

# %% [markdown]
# # Call Expressions

# %% [markdown]
# [Expression Evaluation Process](expressions.pdf)

# %% [markdown]
# ## Lets evaluate some call expressions!!

# %%
from operator import mul,add

# %%
add ( 2, 3)
# Out:
# 5

# %%
mul(add(2,4),5)
# Out:
# 30

# %%
mul(add(4, mul(4, 6)), add(3, 5))
# Out:
# 224

# %%
max(7, 9, 12,2,45)
# Out:
# 45

# %%
min(2+25, 9)
# Out:
# 9

# %%
pow(4, 3)
# Out:
# 64

# %%
max( min(1, -2) , min( pow(3, 5) , -4)    )
# Out:
# -2

# %%
a = [(4, 'a'), (3, 'b', 5), ('c', 5, 7)]
type(a)
# Out:
# list

# %%
type(a[0][0])
# Out:
# int

# %%
type(a[2][0])
# Out:
# str

# %%
type(1/2)
# Out:
# float

# %%
x = '''
A cube has 8 corners:

          7------8
         /|     /|
        3------4 |
        | |    | |
        | 5----|-6
        |/     |/
        1------2

'''
print(x)
# Out:
# A cube has 8 corners:
#
#           7------8
#          /|     /|
#         3------4 |
#         | |    | |
#         | 5----|-6
#         |/     |/
#         1------2
